# %%
import nltk
nltk.download('punkt_tab')
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\asus\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.

# %%
word_tokenize("NLCP is transformng how machine understand text.")
# Out:
# ['NLCP', 'is', 'transformng', 'how', 'machine', 'understand', 'text', '.']

# %%
word_tokenize("NLP is quite exciting and good.")
# Out:
# ['NLP', 'is', 'quite', 'exciting', 'and', 'good', '.']
